# %% [markdown]
# # Create clients tables

# %%
# %run ./create_clients_tbls.ipynb
# Out:
# Importing following functions: normalize_date_col(), normalize_str_col(), get_all_files()
#
# file name: clients_MOCK.csv
# client_id_col: customer_key / name_col: display_name / date_col: signup_ts / other_columns: ['active_flag', 'currency']
# Client_id doesn't follow C01234 formatting! Client_id Value: Cdjao
# clients_MOCK.csv failed validation check.
#
# file name: clients_v1.pdf
# client_id_col: client_id / name_col: client_name / date_col: created_at / other_columns: ['status']
#    client_id          company_name    status cli_join_dt
# 0     C15499       Zenith Holdings    ACTIVE  2020-05-17
# 1     C64279       Green Logistics    ACTIVE  2022-11-06
# 2     C94929              Green Co    ACTIVE  2021-11-27
# 3     C43677            Apex Group  INACTIVE  2019-05-24
# 4     C97125       Blue Industries    ACTIVE  2021-09-14
# 5     C10456         Blue Partners  INACTIVE  2023-11-03
# 6     C77726       Nimbus Holdings    ACTIVE  2021-09-25
# ...

# %% [markdown]
# # Create Invoices tables

# %%
# %run ./create_invoices_tbls.ipynb
# Out:
# Importing following functions: normalize_date_col(), normalize_str_col(), get_all_files()
#
# file name: invoices_MOCK.csv
# invoice_id_col: invoice_id / date_col: invoice_date / shpmnt_col: shipment_type
# invoice_id doesn't follow INV-ABC1234 formatting! invoice_id Value: INV-N9Z2HI7fsd
# invoices_MOCK.csv failed validation check.
#
# file name: invoices_v1.csv
# invoice_id_col: invoice_id / date_col: invoice_date / shpmnt_col: shipment_type
#         invoice_id client_id invoice_date    amount currency shipment_type
# 0      INV-ITBHR2P    C10456   2025-05-22   5235.33      USD          2DAY
# 1      INV-LWC0YM6    C16655   2024-04-19   3015.04      USD        GROUND
# 2      INV-7TDN2MF    C63096   2025-07-28   3023.94      USD        GROUND
# 3      INV-N9Z2HI7    C15499   2025-05-30   3253.71      USD        GROUND
# 4      INV-M8ZSF57    C93089   2024-07-14   3526.16      USD        GROUND
# ...            ...       ...          ...       ...      ...           ...
# ...

# %% [markdown]
# # Create Rate Sheet Table

# %%
# %run "./create_rate_sheet.ipynb"
# Out:
# rate_sheet.csv table created at ../output_tables/rate_sheet.csv!
#   shipment_type  rate
# 0        GROUND     1
# 1          2DAY     5
# 2       EXPRESS    10
# 3       FREIGHT    20

# %% [markdown]
# # Analysis Questions

# %%
# %run "./analysis questions.ipynb"
# Out:
#       client_id      company_name   invoice_id invoice_date  invoice_amt  \
# 0        C10456     Blue Partners  INV-ITBHR2P   2025-05-22      5654.16
# 1        C16655          hooli co  INV-LWC0YM6   2024-04-19      3165.79
# 2        C63096   Initech Freight  INV-7TDN2MF   2025-07-28      3326.33
# 3        C15499   Zenith Holdings  INV-N9Z2HI7   2025-05-30      3514.01
# 4        C93089       Blue Supply  INV-M8ZSF57   2024-07-14      3702.47
# ...         ...               ...          ...          ...          ...
# 11995    C63096   Initech Freight  INV-5LPB2GE   2025-12-06      3510.99
# 11996    C86029   Acme Industries  INV-CE1RRD5   2025-09-05     15561.43
# 11997    C57382  Vector Logistics  INV-SU0IUIL   2025-01-26      2700.09
# 11998    C17172      Apex Freight  INV-FH9UUJM   2025-05-19     42958.88
# 11999    C98399       Wayne Group  INV-05K9AA2   2024-07-16      2020.58
#
#       currency shipment_type  rate
# 0          USD          2DAY     5
# ...
